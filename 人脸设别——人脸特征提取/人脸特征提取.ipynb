# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import fetch_lfw_people

# %%
faces=fetch_lfw_people()
faces.data.shape
# Out:
# (13233, 2914)

# %%
faces.images.shape
# Out:
# (13233, 62, 47)

# %%
#faces_index=np.random.permutation(len(faces.data))
x=faces.data[faces_index]
example_faces=x[:7,:]
example_faces.shape
# Out:
# (7, 2914)

# %%
def plot_digits(data):
    fig,axes = plt.subplots(1,7,figsize=(10,10),
    subplot_kw={'xticks':[],'yticks':[]},
    gridspec_kw=dict(hspace=0.1,wspace=0.1))
    for i,ax in enumerate(axes.flat):
        ax.imshow(data[i].reshape(62,47),cmap='bone')

# %%
plot_digits (example_faces)

# %%
faces.target_names
# Out:
# array(['AJ Cook', 'AJ Lamas', 'Aaron Eckhart', ..., 'Zumrati Juma',
#        'Zurab Tsereteli', 'Zydrunas Ilgauskas'], dtype='<U35')

# %%
len(faces.target_names)
# Out:
# 5749

# %%
x,y=faces.data,faces.target
from sklearn.decomposition import PCA

# %%
pca=PCA(svd_solver='randomized')
pca.fit(example_faces)
pca.components_.shape
# Out:
# (7, 2914)

# %%
plot_digits(pca.components_)
